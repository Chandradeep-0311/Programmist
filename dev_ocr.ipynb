# %%
##libraries to read images
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
##read the image
img = mpimg.imread('505.jpg')
print(type(img))
print(img.shape)
plt.imshow(img)
# Out:
# <class 'numpy.ndarray'>
# (800, 600, 3)
